# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import h5py as hdf
from IPython.display import display
from numba import jit
from scipy.signal import savgol_filter as sgy
import shutil
plt.rcParams['figure.facecolor'] = 'white'

# %%
ts=pd.read_csv('data/try.txt',header=[1],index_col=0,sep='\\t',decimal=',')
display(ts)
ts.drop('Strain/strain',axis=0,inplace=True)
ts['Lgr. Principal Strain 1']=ts['Lgr. Principal Strain 1'].astype('float')
ts['Uncertainty of Lgr. Principal Strain 1']=ts['Lgr. Principal Strain 1'].astype('float')
ts.index.astype('float')
# Out:
# <ipython-input-59-a865b82e51db>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ts=pd.read_csv('data/try.txt',header=[1],index_col=0,sep='\\t',decimal=',')
#               Lgr. Principal Strain 1  Uncertainty of Lgr. Principal Strain 1
# Step No.
# Strain/strain           Strain/strain                                     NaN
# 0                                   0                                0.000104
# 1                          0.00246928                                0.001564
# 2                          0.00375094                                0.001582
# 3                          0.00333129                                0.001630
# ...                               ...                                     ...
# ...

# %%
display(np.array(ts['Lgr. Principal Strain 1']))

plt.figure(figsize=(20,15))
plt.plot(ts.index,ts['Lgr. Principal Strain 1'])
plt.plot(ts.index,sgy(ts['Lgr. Principal Strain 1'],21,3),lw=4)
plt.show()
# Out:
# array([0.        , 0.00246928, 0.00375094, 0.00333129, 0.00271904,
#        0.00252876, 0.00243813, 0.00277173, 0.00233837, 0.00521751,
#        0.00240338, 0.00343385, 0.00074905, 0.00446949, 0.0008933 ,
#        0.00254189, 0.00290737, 0.00251391, 0.00314064, 0.00427459,
#        0.00553889, 0.00166566, 0.00230181, 0.00192269, 0.00219759,
#        0.003408  , 0.00057458, 0.00287378, 0.00294752, 0.00507635,
#        0.00128268, 0.00340335, 0.00396267, 0.00305421, 0.00302076,
#        0.00193645, 0.00348355, 0.0024994 , 0.00336085, 0.00353619,
#        0.00505328, 0.0017322 , 0.00269769, 0.00398801, 0.00344512,
#        0.00395356, 0.00552719, 0.00203003, 0.00205331, 0.00271256,
#        0.00455711, 0.00263562, 0.00439411, 0.00303799, 0.00155711,
#        0.00260273, 0.00694309, 0.00738141, 0.00638973, 0.00863341,
#        0.00615635, 0.00837787, 0.00674373, 0.00499113, 0.00660274,
#        0.00426936, 0.00614165, 0.00615955, 0.00888079, 0.00457446,
# ...
